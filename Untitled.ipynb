# %%
import pandas as pd

# %%
df=pd.read_csv('book.csv')

# %%
df.drop(columns=['user_id','rating','publisher','no of ratings'],inplace=True)

# %%
df=df.iloc[:,1:]

# %%
df
# Out:
#              ISBN                                              title  \
# 0      002542730X  Politically Correct Bedtime Stories: Modern Ta...
# 1      002542730X  Politically Correct Bedtime Stories: Modern Ta...
# 2      002542730X  Politically Correct Bedtime Stories: Modern Ta...
# 3      002542730X  Politically Correct Bedtime Stories: Modern Ta...
# 4      002542730X  Politically Correct Bedtime Stories: Modern Ta...
# ...           ...                                                ...
# 59845  0553579983                                   And Then You Die
# 59846  0553579983                                   And Then You Die
# 59847  0553579983                                   And Then You Die
# 59848  0553579983                                   And Then You Die
# 59849  0553579983                                   And Then You Die
#
#                   author  Year-Of-Publication  \
# 0      James Finn Garner                 1994
# ...

# %%
import pickle

# %%
model=pickle.load(open('model.pkl','rb'))

# %%
pt=pickle.load(open('pt.pkl','rb'))

# %%
pt
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
df.shape
# Out:
# (59850, 5)

# %%
pt.index
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        '84 Charing Cross Road', 'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Cry In The Night',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='title', length=742)

# %%
def func(prompt):
    index=np.where
# Out:
# True

# %%
import numpy as np

# %%
index=np.where(pt.index=='1984')[0][0]

# %%
d,s=model.kneighbors(pt.iloc[index,:].values.reshape(1,-1),n_neighbors=6)

# %%
s
# Out:
# array([[  0, 372,   8, 212, 320,  33]], dtype=int64)

# %%
t=[]
for i in range(1,len(s[0])):
    print(pt.index[i])
    t.append(pt.index[i])
# Out:
# 1st to Die: A Novel
# 2nd Chance
# 4 Blondes
# 84 Charing Cross Road
# A Bend in the Road

# %%
t
# Out:
# ['1st to Die: A Novel',
#  '2nd Chance',
#  '4 Blondes',
#  '84 Charing Cross Road',
#  'A Bend in the Road']

# %%
df.head()
# Out:
#          ISBN                                              title  \
# 0  002542730X  Politically Correct Bedtime Stories: Modern Ta...
# 1  002542730X  Politically Correct Bedtime Stories: Modern Ta...
# 2  002542730X  Politically Correct Bedtime Stories: Modern Ta...
# 3  002542730X  Politically Correct Bedtime Stories: Modern Ta...
# 4  002542730X  Politically Correct Bedtime Stories: Modern Ta...
#
#               author  Year-Of-Publication  \
# 0  James Finn Garner                 1994
# 1  James Finn Garner                 1994
# 2  James Finn Garner                 1994
# 3  James Finn Garner                 1994
# 4  James Finn Garner                 1994
#
#                                                image
# 0  http://images.amazon.com/images/P/002542730X.0...
# 1  http://images.amazon.com/images/P/002542730X.0...
# 2  http://images.amazon.com/images/P/002542730X.0...
# 3  http://images.amazon.com/images/P/002542730X.0...
# ...

# %%
df
# Out:
#              ISBN                                              title  \
# 0      002542730X  Politically Correct Bedtime Stories: Modern Ta...
# 1      002542730X  Politically Correct Bedtime Stories: Modern Ta...
# 2      002542730X  Politically Correct Bedtime Stories: Modern Ta...
# 3      002542730X  Politically Correct Bedtime Stories: Modern Ta...
# 4      002542730X  Politically Correct Bedtime Stories: Modern Ta...
# ...           ...                                                ...
# 59845  0553579983                                   And Then You Die
# 59846  0553579983                                   And Then You Die
# 59847  0553579983                                   And Then You Die
# 59848  0553579983                                   And Then You Die
# 59849  0553579983                                   And Then You Die
#
#                   author  Year-Of-Publication  \
# 0      James Finn Garner                 1994
# ...

# %%
df.drop_duplicates(['title','author','Year-Of-Publication'],inplace=True)

# %%
df.loc[df['title']==pd.Series(t,name='title')[0]]
# Out:
#              ISBN                title           author  Year-Of-Publication  \
# 43106  0446610038  1st to Die: A Novel  James Patterson                 2002
# 43233  0316666009  1st to Die: A Novel  James Patterson                 2001
#
#                                                    image
# 43106  http://images.amazon.com/images/P/0446610038.0...
# 43233  http://images.amazon.com/images/P/0316666009.0...

# %%
d=pd.DataFrame(columns=df.columns)

# %%
d
# Out:
# Empty DataFrame
# Columns: [ISBN, title, author, Year-Of-Publication, image]
# Index: []

# %%
for i in t:
    row=df.loc[df['title']==i]
    d=pd.concat([d,row],ignore_index=True,axis=0,)

# %%
d.drop_duplicates(['title'],inplace=True)

# %%
d
# Out:
#          ISBN                  title            author Year-Of-Publication  \
# 0  0446610038    1st to Die: A Novel   James Patterson                2002
# 2  0446612790             2nd Chance   James Patterson                2003
# 5  0451203895              4 Blondes  Candace Bushnell                2002
# 6  0140143505  84 Charing Cross Road      Helene Hanff                1990
# 9  0446527785     A Bend in the Road   Nicholas Sparks                2001
#
#                                                image
# 0  http://images.amazon.com/images/P/0446610038.0...
# 2  http://images.amazon.com/images/P/0446612790.0...
# 5  http://images.amazon.com/images/P/0451203895.0...
# 6  http://images.amazon.com/images/P/0140143505.0...
# 9  http://images.amazon.com/images/P/0446527785.0...

# %%
def get(promt):
    index=np.where(pt.index==promt)
    d,s=model.kneighbors(pt.iloc[index[0][0],:].values.reshape(1,-1),n_neighbors=6)
    n=pd.DataFrame(columns=df.columns)
    m=[]
    for i in range(1,len(s[0])):
        # print(pt.index[s[0][i]])
        m.append(pt.index[s[0][i]])    
    for i in m:
        row=df.loc[df['title']==i]
        n=pd.concat([n,row],ignore_index=True)
    n.drop_duplicates(['title'],inplace=True)
    return n

# %%
new=get('A Bend in the Road')

# %%
new
# Out:
#           ISBN                 title                   author  \
# 0   0446604232             Exclusive             Sandra Brown
# 2   0440115450  The Cradle Will Fall       Mary Higgins Clark
# 4   0345404777         No Safe Place  RICHARD NORTH PATTERSON
# 7   0440124344          Family Album           Danielle Steel
# 10  0140092323     Lake Wobegon days         Garrison Keillor
#
#    Year-Of-Publication                                              image
# 0                 1997  http://images.amazon.com/images/P/0446604232.0...
# 2                 1983  http://images.amazon.com/images/P/0440115450.0...
# 4                 1999  http://images.amazon.com/images/P/0345404777.0...
# 7                 1989  http://images.amazon.com/images/P/0440124344.0...
# 10                1986  http://images.amazon.com/images/P/0140092323.0...

# %%
new['image'][0]
# Out:
# 'http://images.amazon.com/images/P/0446604232.01.MZZZZZZZ.jpg'

# %%
df.reset_index(inplace=True)

# %%
df=df.iloc[:,1:]

# %%
df
# Out:
#             ISBN                                              title  \
# 0     002542730X  Politically Correct Bedtime Stories: Modern Ta...
# 1     0060930535                      The Poisonwood Bible: A Novel
# 2     0060934417                                 Bel Canto: A Novel
# 3     0061009059  One for the Money (Stephanie Plum Novels (Pape...
# 4     006440188X                                  The Secret Garden
# ...          ...                                                ...
# 1857  0752837680                                       Still Waters
# 1858  0743439651                                       Still Waters
# 1859  0061090956                                       Still Waters
# 1860  0613224450                                       Still Waters
# 1861  0553579983                                   And Then You Die
#
#                        author  Year-Of-Publication  \
# 0           James Finn Garner                 1994
# ...

# %%
df.to_csv("books.csv",index=False)
